# %% [markdown]
# # 載入 IMDB 資料集

# %%
import tensorflow as tf

dataset = tf.keras.utils.get_file(
    fname="aclImdb.tar.gz", 
    origin="http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz", 
    extract=True,
)
# Out:
# Downloading data from http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# 84131840/84125825 [==============================] - 1s 0us/step

# %% [markdown]
# # 資料集處理
#     正負評價分開、並且編碼。

# %%
import os
import glob
import pandas as pd

def read(fp):
    with open(fp, "r", encoding="utf-8") as f:
        content = f.read()
    return content

def read_data(base):
    pos = glob.glob(os.path.join(base, "pos", "*"))
    neg = glob.glob(os.path.join(base, "neg", "*"))
    df = pd.DataFrame({
        "path":(neg + pos),
        "target":([0]*len(neg) + [1] * len(pos))
    })
    df["content"] = df["path"].apply(read)
    return df

# %%
dirname = os.path.dirname(dataset)
base = os.path.join(dirname, "aclImdb", "train")
train_df = read_data(base)
base = os.path.join(dirname, "aclImdb", "test")
test_df = read_data(base)
test_df
# Out:
#                                                     path  ...                                            content
# 0      /root/.keras/datasets/aclImdb/test/neg/11722_4...  ...  I saw this film for one reason: the tagline is...
# 1      /root/.keras/datasets/aclImdb/test/neg/1571_4.txt  ...  The film was disappointing. I saw it on Broadw...
# 2      /root/.keras/datasets/aclImdb/test/neg/8224_1.txt  ...  OK, so I gotta start this review by saying i w...
# 3      /root/.keras/datasets/aclImdb/test/neg/10426_4...  ...  This movie narrate the story of John Belushi,b...
# 4      /root/.keras/datasets/aclImdb/test/neg/6390_2.txt  ...  This movie just arrived to Mexico and since I ...
# ...                                                  ...  ...                                                ...
# 24995  /root/.keras/datasets/aclImdb/test/pos/11181_8...  ...  On account of my unfortunately not being able ...
# 24996  /root/.keras/datasets/aclImdb/test/pos/8188_10...  ...  This movie is beautiful in many ways: the plot...
# 24997  /root/.keras/datasets/aclImdb/test/pos/3098_8.txt  ...  One of the most entertaining of all silent com...
# 24998  /root/.keras/datasets/aclImdb/test/pos/10878_1...  ...  Two years after its initial release, Goldeneye...
# 24999  /root/.keras/datasets/aclImdb/test/pos/7443_8.txt  ...  The movie is really cool, I thought. It sticks...
#
# [25000 rows x 3 columns]

# %% [markdown]
# # 文字預處理 (text to number)

# %%
# 預處理1. 先把文字化成數字
from tensorflow.keras.preprocessing.text import Tokenizer
# 出現太少的詞, 你可以選擇不看, 只留出現次數最高的2000(num_words)
tok = Tokenizer(num_words=2000)
tok.fit_on_texts(train_df["content"])

# %%
# 想要看每個單詞被給的編號: 
# tok.word_index

# %%
x_train_seq = tok.texts_to_sequences(train_df["content"])
x_test_seq = tok.texts_to_sequences(test_df["content"])
pd.DataFrame(x_train_seq)
# Out:
#        0     1     2     3     4     5     ...  1705  1706  1707  1708  1709  1710
# 0         2   104     4    58   219  1636  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 1         1   436    16     1     6    53  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2        51    10    11    17    36     3  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3         3   220    16  1243  1627   155  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4       259    10   358    11   176     5  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 24995   540     6     3   640  1841   170  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 24996    10  1038    16   313    34   555  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 24997   320   672    52    49   861    22  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 24998    28     4    58  1636    99    10  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 24999     2  1351     1  1747   894   633  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
# [25000 rows x 1711 columns]

# %% [markdown]
# # 句子 NAN 填充

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

x_train_pad = pad_sequences(x_train_seq, maxlen=256)
x_test_pad = pad_sequences(x_test_seq, maxlen=256)
pd.DataFrame(x_train_pad)
# Out:
#         0    1    2    3     4    5    ...   250  251   252   253   254  255
# 0       215   14  335    4    32  520  ...    19  487    88  1326  1656  140
# 1         1  357    4   24   110    8  ...  1849    5   273     1    20   65
# 2         0    0    0    0     0    0  ...   744  208   125    71    11  592
# 3      1026    1  664   31  1657  708  ...    89   27     8     3   368  721
# 4         0    0    0    0     0    0  ...    58  110     2    46   946   49
# ...     ...  ...  ...  ...   ...  ...  ...   ...  ...   ...   ...   ...  ...
# 24995     0    0    0    0     0    0  ...   878    2  1790     4    11   17
# 24996     0    0    0    0     0    0  ...    13  477    26     6   207  477
# 24997     0    0    0    0     0    0  ...  1131    2    42  1117    52   70
# 24998     0    0    0    0     0    0  ...    86    5    78    12     7    7
# 24999    18   22  356   21  1089   85  ...     1  357     4     1    17  598
#
# [25000 rows x 256 columns]

# %% [markdown]
# # 模型建立

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Flatten, Dropout, Dense

layers = [
    # 2001 * 64 = 128064
    Embedding(2001, 64, mask_zero=True, input_length=256),
    Flatten(),
    Dense(256, activation="relu"),
    Dropout(0.25),
    Dense(2, activation="softmax")
]
model = Sequential(layers)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 256, 64)           128064
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               4194560
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 514
# =================================================================
# Total params: 4,323,138
# Trainable params: 4,323,138
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 模型編譯

# %%
from tensorflow.keras.losses import SparseCategoricalCrossentropy
model.compile(loss=SparseCategoricalCrossentropy(),
              optimizer="adam",
              metrics=["accuracy"])

# %% [markdown]
# # 模型訓練

# %%
import numpy as np
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
callbacks = [
    EarlyStopping(patience=3, restore_best_weights=True),
]
model.fit(x_train_pad,
          np.array(train_df["target"]),
          batch_size=200,
          epochs=100,
          validation_split=0.1,
          verbose=2,
          callbacks=callbacks)
# Out:
# Epoch 1/100
# 113/113 - 15s - loss: 0.5282 - accuracy: 0.7081 - val_loss: 0.4840 - val_accuracy: 0.7960
# Epoch 2/100
# 113/113 - 15s - loss: 0.2111 - accuracy: 0.9176 - val_loss: 0.3553 - val_accuracy: 0.8552
# Epoch 3/100
# 113/113 - 15s - loss: 0.0736 - accuracy: 0.9773 - val_loss: 0.4488 - val_accuracy: 0.8444
# Epoch 4/100
# 113/113 - 15s - loss: 0.0167 - accuracy: 0.9972 - val_loss: 0.6650 - val_accuracy: 0.8304
# Epoch 5/100
# 113/113 - 15s - loss: 0.0042 - accuracy: 0.9996 - val_loss: 0.7824 - val_accuracy: 0.8208

# %% [markdown]
# # 模型驗證

# %%
model.evaluate(x_test_pad, np.array(test_df["target"]))
# Out:
# 782/782 [==============================] - 6s 8ms/step - loss: 0.3365 - accuracy: 0.8590
# [0.33653995394706726, 0.858959972858429]

# %% [markdown]
# # 預測資料

# %%
layers = [
    # 2001 * 64 = 128064
    Embedding(2001, 64, mask_zero=True),
]
embedding = Sequential(layers)
w = model.layers[0].get_weights()
embedding.set_weights(w)
embedding.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 64)          128064
# =================================================================
# Total params: 128,064
# Trainable params: 128,064
# Non-trainable params: 0
# _________________________________________________________________

# %%
embedding.predict([[1]])
# Out:
# array([[[-0.0180213 ,  0.01985464,  0.02356286, -0.03132242,
#           0.00996363, -0.03841089,  0.03119331, -0.01875136,
#           0.01503539,  0.0453583 , -0.03884904,  0.00555581,
#           0.01781305, -0.01935773, -0.03558391, -0.01774406,
#          -0.0171569 ,  0.00849898,  0.02612113,  0.00717588,
#           0.02580583,  0.02318492, -0.0097551 ,  0.02422469,
#          -0.0281295 ,  0.00059863,  0.01478149,  0.00800881,
#          -0.0003116 , -0.03357462, -0.00507779, -0.03138198,
#           0.01264676, -0.03298078, -0.02271628,  0.0205271 ,
#          -0.02204996,  0.03441257,  0.0160019 , -0.0340315 ,
#           0.01385654, -0.0067904 ,  0.01141077, -0.01508256,
#           0.00136489, -0.01414987,  0.00065778, -0.02574585,
#          -0.04049654, -0.01858634,  0.00316737, -0.02689118,
#          -0.01500137,  0.02210342,  0.01340085,  0.01668786,
#           0.02157978,  0.00375725,  0.01285978, -0.03685961,
#          -0.00817791, -0.01694725, -0.00168056,  0.03617594]]],
#       dtype=float32)
