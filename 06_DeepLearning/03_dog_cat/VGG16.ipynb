# %% [markdown]
# # 載入套件 Loading Package

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Flatten, Dense, BatchNormalization, Activation, GlobalAveragePooling2D
from tensorflow.keras.applications import VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # 初始化 Initial

# %%
DATASET_PATH = '/content/drive/My Drive/Colab Notebooks/DogVsCat/dogs-cats-small-dataset' # 資料路徑
IMAGE_SIZE = (224, 224) # 影像大小
NUM_CLASSES = 2         # 影像類別數量
BATCH_SIZE = 8          # 若 GPU 記憶體不足，可調降 batch size 或 凍結更多層網路
FREEZE_LAYERS = 2       # 凍結網路層數
NUM_EPOCHES = 50         # Epoch 數量
WEIGHTS_FINAL = 'model-VGG16-final.h5' # 模型輸出儲存的檔案

# %% [markdown]
# # 資料增強 Data augmentation

# %%
# 透過 data augmentation 產生訓練與驗證用的影像資料
train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest')

train_batches = train_datagen.flow_from_directory(DATASET_PATH + '/train',
                                                  target_size=IMAGE_SIZE,
                                                  interpolation='bicubic',
                                                  class_mode='categorical',
                                                  shuffle=True,
                                                  batch_size=BATCH_SIZE)

valid_datagen = ImageDataGenerator()
valid_batches = valid_datagen.flow_from_directory(DATASET_PATH + '/validation',
                                                 target_size= IMAGE_SIZE,
                                                 interpolation= 'bicubic',
                                                 class_mode= 'categorical',
                                                 shuffle= False,
                                                 batch_size=BATCH_SIZE)

# 輸出各類別的索引
for c, idx in train_batches.class_indices.items():
    print('Class #{} = {}'.format(idx, c))
# Out:
# Found 200 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Class #0 = cats
# Class #1 = dogs

# %% [markdown]
# # 建立模型 Build Model

# %%
# 捨棄 VGG16 的 fully connected layers
net = VGG16(include_top=False, 
               weights='imagenet', 
               input_tensor=None,
               input_shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

for layer in net.layers:
    layer.trainable = True

x = net.output
# BN-relu + GAP2D
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = GlobalAveragePooling2D()(x)
# 增加 Dense layer，以 softmax 產生各類別的機率值
output_layer = Dense(NUM_CLASSES, activation='softmax')(x)

net_final = Model(inputs=net.input, outputs=output_layer)
    
# 使用 Adam optimizer，以較低的 learning rae 進行 fine-tuning
net_final.compile(optimizer=Adam(lr=1e-5),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step

# %% [markdown]
# # 網路結構 Net Structure

# %%
# 輸出整個網路結構
print(net_final.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 7, 7, 512)         2048
# _________________________________________________________________
# activation (Activation)      (None, 7, 7, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 2)                 1026
# =================================================================
# Total params: 14,717,762
# Trainable params: 14,716,738
# Non-trainable params: 1,024
# _________________________________________________________________
# None

# %% [markdown]
# # 訓練模型 Training Model

# %%
history = net_final.fit_generator(train_batches,
                                  steps_per_epoch= train_batches.samples // BATCH_SIZE, 
                                  validation_data= valid_batches,
                                  validation_steps= valid_batches.samples // BATCH_SIZE,
                                  epochs= NUM_EPOCHES)
# Out:
# WARNING:tensorflow:From <ipython-input-6-ddb623c62ef7>:5: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/50
# 25/25 [==============================] - 170s 7s/step - loss: 0.6173 - accuracy: 0.6350 - val_loss: 0.8954 - val_accuracy: 0.6250
# Epoch 2/50
# 25/25 [==============================] - 4s 173ms/step - loss: 0.4591 - accuracy: 0.8400 - val_loss: 0.4961 - val_accuracy: 0.8021
# Epoch 3/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.3930 - accuracy: 0.8850 - val_loss: 0.3878 - val_accuracy: 0.8646
# Epoch 4/50
# 25/25 [==============================] - 4s 171ms/step - loss: 0.3023 - accuracy: 0.9300 - val_loss: 0.3656 - val_accuracy: 0.8542
# Epoch 5/50
# 25/25 [==============================] - 5s 181ms/step - loss: 0.2559 - accuracy: 0.9250 - val_loss: 0.2748 - val_accuracy: 0.8854
# Epoch 6/50
# 25/25 [==============================] - 5s 181ms/step - loss: 0.2430 - accuracy: 0.9400 - val_loss: 0.3159 - val_accuracy: 0.8854
# Epoch 7/50
# 25/25 [==============================] - 5s 183ms/step - loss: 0.2459 - accuracy: 0.9350 - val_loss: 0.2316 - val_accuracy: 0.9062
# Epoch 8/50
# 25/25 [==============================] - 5s 183ms/step - loss: 0.1894 - accuracy: 0.9600 - val_loss: 0.3866 - val_accuracy: 0.8542
# Epoch 9/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.1821 - accuracy: 0.9700 - val_loss: 0.1937 - val_accuracy: 0.9167
# Epoch 10/50
# 25/25 [==============================] - 4s 179ms/step - loss: 0.1427 - accuracy: 0.9750 - val_loss: 0.3458 - val_accuracy: 0.8542
# Epoch 11/50
# 25/25 [==============================] - 5s 182ms/step - loss: 0.1295 - accuracy: 0.9800 - val_loss: 0.1738 - val_accuracy: 0.9271
# Epoch 12/50
# 25/25 [==============================] - 5s 181ms/step - loss: 0.1287 - accuracy: 0.9700 - val_loss: 0.1701 - val_accuracy: 0.9271
# Epoch 13/50
# 25/25 [==============================] - 4s 177ms/step - loss: 0.0953 - accuracy: 0.9900 - val_loss: 0.1555 - val_accuracy: 0.9479
# Epoch 14/50
# 25/25 [==============================] - 5s 181ms/step - loss: 0.0915 - accuracy: 0.9900 - val_loss: 0.1634 - val_accuracy: 0.9271
# Epoch 15/50
# 25/25 [==============================] - 5s 181ms/step - loss: 0.1310 - accuracy: 0.9700 - val_loss: 0.1715 - val_accuracy: 0.9375
# Epoch 16/50
# 25/25 [==============================] - 4s 177ms/step - loss: 0.1083 - accuracy: 0.9650 - val_loss: 0.2223 - val_accuracy: 0.9271
# Epoch 17/50
# 25/25 [==============================] - 4s 178ms/step - loss: 0.0975 - accuracy: 0.9750 - val_loss: 0.1709 - val_accuracy: 0.9167
# Epoch 18/50
# 25/25 [==============================] - 4s 177ms/step - loss: 0.0789 - accuracy: 0.9900 - val_loss: 0.1845 - val_accuracy: 0.9167
# Epoch 19/50
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0655 - accuracy: 0.9950 - val_loss: 0.1452 - val_accuracy: 0.9375
# Epoch 20/50
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0623 - accuracy: 1.0000 - val_loss: 0.2011 - val_accuracy: 0.9167
# Epoch 21/50
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0504 - accuracy: 1.0000 - val_loss: 0.1611 - val_accuracy: 0.9271
# Epoch 22/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0586 - accuracy: 0.9950 - val_loss: 0.1455 - val_accuracy: 0.9375
# Epoch 23/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0698 - accuracy: 0.9900 - val_loss: 0.1565 - val_accuracy: 0.9271
# Epoch 24/50
# 25/25 [==============================] - 4s 177ms/step - loss: 0.0458 - accuracy: 0.9900 - val_loss: 0.3009 - val_accuracy: 0.8958
# Epoch 25/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0489 - accuracy: 0.9900 - val_loss: 0.1528 - val_accuracy: 0.9479
# Epoch 26/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0484 - accuracy: 0.9950 - val_loss: 0.1975 - val_accuracy: 0.9167
# Epoch 27/50
# 25/25 [==============================] - 4s 178ms/step - loss: 0.0397 - accuracy: 0.9950 - val_loss: 0.1487 - val_accuracy: 0.9271
# Epoch 28/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0321 - accuracy: 0.9950 - val_loss: 0.2120 - val_accuracy: 0.9271
# Epoch 29/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.1494 - val_accuracy: 0.9375
# Epoch 30/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0328 - accuracy: 0.9950 - val_loss: 0.1640 - val_accuracy: 0.9375
# Epoch 31/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0458 - accuracy: 0.9850 - val_loss: 0.2255 - val_accuracy: 0.9062
# Epoch 32/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0361 - accuracy: 0.9950 - val_loss: 0.2689 - val_accuracy: 0.8958
# Epoch 33/50
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0361 - accuracy: 0.9950 - val_loss: 0.1211 - val_accuracy: 0.9583
# Epoch 34/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0375 - accuracy: 0.9900 - val_loss: 0.4142 - val_accuracy: 0.8750
# Epoch 35/50
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0296 - accuracy: 1.0000 - val_loss: 0.1891 - val_accuracy: 0.9167
# Epoch 36/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0687 - accuracy: 0.9800 - val_loss: 0.1234 - val_accuracy: 0.9479
# Epoch 37/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0349 - accuracy: 0.9900 - val_loss: 0.1681 - val_accuracy: 0.9062
# Epoch 38/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0386 - accuracy: 0.9900 - val_loss: 0.2352 - val_accuracy: 0.9062
# Epoch 39/50
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.1153 - val_accuracy: 0.9583
# Epoch 40/50
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.3146 - val_accuracy: 0.9062
# Epoch 41/50
# 25/25 [==============================] - 4s 178ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.1438 - val_accuracy: 0.9583
# Epoch 42/50
# 25/25 [==============================] - 4s 177ms/step - loss: 0.0396 - accuracy: 1.0000 - val_loss: 0.1635 - val_accuracy: 0.9271
# Epoch 43/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0218 - accuracy: 0.9950 - val_loss: 0.2613 - val_accuracy: 0.9062
# Epoch 44/50
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0184 - accuracy: 1.0000 - val_loss: 0.1412 - val_accuracy: 0.9375
# Epoch 45/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.1775 - val_accuracy: 0.9271
# Epoch 46/50
# 25/25 [==============================] - 4s 173ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.1141 - val_accuracy: 0.9479
# Epoch 47/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.1624 - val_accuracy: 0.9375
# Epoch 48/50
# 25/25 [==============================] - 4s 175ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.1102 - val_accuracy: 0.9479
# Epoch 49/50
# 25/25 [==============================] - 4s 174ms/step - loss: 0.0116 - accuracy: 1.0000 - val_loss: 0.1946 - val_accuracy: 0.9167
# Epoch 50/50
# 25/25 [==============================] - 4s 176ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.2511 - val_accuracy: 0.9167

# %% [markdown]
# # 儲存模型 Save Model

# %%
net_final.save(WEIGHTS_FINAL)

# %% [markdown]
# # 視覺化 Visualize
#     觀察 accuracy、loss 變化

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

loss = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1,len(acc)+1)

plt.plot(epochs,acc,'bo',label = 'Training acc')
plt.plot(epochs,val_acc,'b',label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs,loss,'bo',label = 'Training loss')
plt.plot(epochs,val_loss,'b',label = 'Validation loss')
plt.title("Training and validation loss")
plt.legend()

plt.show()
